# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Step 2: Load dataset
# Replace 'your_dataset_path.csv' with your actual file path
df = pd.read_csv('C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    """
    Tokenizes input text using the BERT tokenizer.
    
    Args:
        tweets: A pandas Series containing text data.
        tokenizer: A BERT tokenizer.
        max_length: The maximum length of the tokenized output.
        
    Returns:
        A dictionary containing input IDs, attention masks, and token type IDs.
    """
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids, df['target'], test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    """
    Converts tokenized inputs and labels into a TensorFlow dataset.
    
    Args:
        inputs: Tokenized input IDs.
        masks: Attention masks for the input IDs.
        labels: Target labels.
        batch_size: The size of batches for the dataset.
        
    Returns:
        A TensorFlow dataset ready for training.
    """
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Output the shapes of datasets
print(f"Training dataset: {train_dataset}")
print(f"Validation dataset: {val_dataset}")

# Your datasets are now ready to be fed into a TensorFlow model
# Out:
#   Cell In[1], line 9
#     df = pd.read_csv('C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Step 2: Load dataset
# Use raw string to avoid unicode escape error or replace backslashes with forward slashes
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')

# Alternatively, replace backslashes with forward slashes
# df = pd.read_csv('C:/Users/ksvsu/OneDrive/Desktop/Minor Project/data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')

df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    """
    Tokenizes input text using the BERT tokenizer.
    
    Args:
        tweets: A pandas Series containing text data.
        tokenizer: A BERT tokenizer.
        max_length: The maximum length of the tokenized output.
        
    Returns:
        A dictionary containing input IDs, attention masks, and token type IDs.
    """
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids, df['target'], test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    """
    Converts tokenized inputs and labels into a TensorFlow dataset.
    
    Args:
        inputs: Tokenized input IDs.
        masks: Attention masks for the input IDs.
        labels: Target labels.
        batch_size: The size of batches for the dataset.
        
    Returns:
        A TensorFlow dataset ready for training.
    """
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Output the shapes of datasets
print(f"Training dataset: {train_dataset}")
print(f"Validation dataset: {val_dataset}")

# Your datasets are now ready to be fed into a TensorFlow model
# Out:
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 50
#      47 attention_masks = tokens['attention_mask']
#      49 # Step 7: Split the data into training and validation sets
# ---> 50 train_inputs, val_inputs, train_labels, val_labels = train_test_split(
#      51     input_ids, df['target'], test_size=0.2, random_state=42
#      52 )
#      53 train_masks, val_masks = train_test_split(attention_masks, test_size=0.2, random_state=42)
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Step 2: Load dataset
# Use raw string to avoid unicode escape error or replace backslashes with forward slashes
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')

# Alternatively, replace backslashes with forward slashes
# df = pd.read_csv('C:/Users/ksvsu/OneDrive/Desktop/Minor Project/data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')

df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    """
    Tokenizes input text using the BERT tokenizer.
    
    Args:
        tweets: A pandas Series containing text data.
        tokenizer: A BERT tokenizer.
        max_length: The maximum length of the tokenized output.
        
    Returns:
        A dictionary containing input IDs, attention masks, and token type IDs.
    """
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids'].numpy()  # Convert to NumPy array
attention_masks = tokens['attention_mask'].numpy()  # Convert to NumPy array

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels, train_masks, val_masks = train_test_split(
    input_ids, df['target'].values, attention_masks, test_size=0.2, random_state=42
)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    """
    Converts tokenized inputs and labels into a TensorFlow dataset.
    
    Args:
        inputs: Tokenized input IDs.
        masks: Attention masks for the input IDs.
        labels: Target labels.
        batch_size: The size of batches for the dataset.
        
    Returns:
        A TensorFlow dataset ready for training.
    """
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Output the shapes of datasets
print(f"Training dataset: {train_dataset}")
print(f"Validation dataset: {val_dataset}")

# Your datasets are now ready to be fed into a TensorFlow model
# Out:
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Training dataset: <_PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'attention_mask': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>
# Validation dataset: <_PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'attention_mask': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
# Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Load and preprocess your dataset as described in previous steps...

# Initialize and train your model as before...

# Step 2: Load dataset
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids, df['target'], test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model
optimizer = Adam(learning_rate=2e-5)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs
)

# Step 12: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 41
#      38 attention_masks = tokens['attention_mask']
#      40 # Step 7: Split the data into training and validation sets
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Step 2: Load dataset
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model
optimizer = Adam(learning_rate=2e-5)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs
)

# Step 12: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 30
#      21 def tokenize_tweets(tweets, tokenizer, max_length=128):
#      22     return tokenizer(
#      23         tweets.tolist(),
#      24         padding=True,
#    (...)
#      27         return_tensors="tf"
#      28     )
# ---> 30 tokens = tokenize_tweets(df['text'], tokenizer)
#      32 # Step 6: Prepare inputs for TensorFlow
#      33 input_ids = tokens['input_ids']
#
# ...

# %%
print(train_dataset)
print(val_dataset)
# Out:
# <_PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'attention_mask': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>
# <_PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'attention_mask': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
import pandas as pd
import random

# Load dataset
df = pd.read_csv('/mnt/data/data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Randomly sample 10% of the dataset
sample_fraction = 0.1  # 10% of the data
df_sampled = df.sample(frac=sample_fraction, random_state=42)

# Truncate tweets to reduce sequence length (optional)
df_sampled['text'] = df_sampled['text'].apply(lambda x: ' '.join(x.split()[:64]))  # Limit to 64 words/tokens

# Check the size of the reduced dataset
print(f"Original dataset size: {df.shape[0]}")
print(f"Sampled dataset size: {df_sampled.shape[0]}")

# Proceed with the sampled dataset for further processing and training
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import random
#       4 # Load dataset
# ----> 5 df = pd.read_csv('/mnt/data/data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
#       6 df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']
#       8 # Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
#
# ...

# %%
import pandas as pd
import random

# Load dataset
df = pd.read_csv('C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Randomly sample 10% of the dataset
sample_fraction = 0.1  # 10% of the data
df_sampled = df.sample(frac=sample_fraction, random_state=42)

# Truncate tweets to reduce sequence length (optional)
df_sampled['text'] = df_sampled['text'].apply(lambda x: ' '.join(x.split()[:64]))  # Limit to 64 words/tokens

# Check the size of the reduced dataset
print(f"Original dataset size: {df.shape[0]}")
print(f"Sampled dataset size: {df_sampled.shape[0]}")

# Proceed with the sampled dataset for further processing and training
# Out:
#   Cell In[2], line 5
#     df = pd.read_csv('C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', header=None, on_bad_lines='skip')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import random

# Load dataset using a raw string or double backslashes
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', header=None, on_bad_lines='skip')
# Or, use double backslashes: 
# df = pd.read_csv('C:\\Users\\ksvsu\\OneDrive\\Desktop\\Minor Project\\data.csv', header=None, on_bad_lines='skip')

df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Randomly sample 10% of the dataset
sample_fraction = 0.1  # 10% of the data
df_sampled = df.sample(frac=sample_fraction, random_state=42)

# Truncate tweets to reduce sequence length (optional)
df_sampled['text'] = df_sampled['text'].apply(lambda x: ' '.join(x.split()[:64]))  # Limit to 64 words/tokens

# Check the size of the reduced dataset
print(f"Original dataset size: {df.shape[0]}")
print(f"Sampled dataset size: {df_sampled.shape[0]}")

# Proceed with the sampled dataset for further processing and training
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 5
#       2 import random
#       4 # Load dataset using a raw string or double backslashes
# ----> 5 df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', header=None, on_bad_lines='skip')
#       6 # Or, use double backslashes:
#       7 # df = pd.read_csv('C:\\Users\\ksvsu\\OneDrive\\Desktop\\Minor Project\\data.csv', header=None, on_bad_lines='skip')
#       9 df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']
#
# ...

# %%
import pandas as pd
import random

# Load dataset using ISO-8859-1 encoding or latin1
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', 
                 encoding='ISO-8859-1',  # You can also try 'latin1'
                 header=None, 
                 on_bad_lines='skip')

df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Randomly sample 10% of the dataset
sample_fraction = 0.1  # 10% of the data
df_sampled = df.sample(frac=sample_fraction, random_state=42)

# Truncate tweets to reduce sequence length (optional)
df_sampled['text'] = df_sampled['text'].apply(lambda x: ' '.join(x.split()[:64]))  # Limit to 64 words/tokens

# Check the size of the reduced dataset
print(f"Original dataset size: {df.shape[0]}")
print(f"Sampled dataset size: {df_sampled.shape[0]}")

# Proceed with the sampled dataset for further processing and training
# Out:
# Original dataset size: 1600000
# Sampled dataset size: 160000

# %%
import pandas as pd
import random

# Load dataset using ISO-8859-1 encoding or latin1
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\data.csv', 
                 encoding='ISO-8859-1',  # You can also try 'latin1'
                 header=None, 
                 on_bad_lines='skip')

df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Randomly sample 10% of the dataset
sample_fraction = 0.1  # 10% of the data
df_sampled = df.sample(frac=sample_fraction, random_state=42)

# Truncate tweets to reduce sequence length (optional)
df_sampled['text'] = df_sampled['text'].apply(lambda x: ' '.join(x.split()[:64]))  # Limit to 64 words/tokens

# Check the size of the reduced dataset
print(f"Original dataset size: {df.shape[0]}")
print(f"Sampled dataset size: {df_sampled.shape[0]}")

# Save the sampled dataset to a new CSV file
output_file = r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv'  # Update path if needed
df_sampled.to_csv(output_file, index=False)

print(f"Sampled dataset saved to: {output_file}")
# Out:
# Original dataset size: 1600000
# Sampled dataset size: 160000
# Sampled dataset saved to: C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Step 2: Load dataset
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model
optimizer = Adam(learning_rate=2e-5)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs
)

# Step 12: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# C:\Users\ksvsu\AppData\Local\Temp\ipykernel_14340\1099600633.py:11: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
# Out:
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# Keyword arguments {'clean_up_tokenization_spaces': False} not recognized.
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Step 2: Load dataset (fix DtypeWarning by specifying dtypes or using low_memory=False)
df = pd.read_csv(
    r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', 
    encoding='ISO-8859-1', 
    header=None, 
    on_bad_lines='skip', 
    low_memory=False  # Avoid mixed type warning
)
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data (fix FutureWarning by setting clean_up_tokenization_spaces=False)
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf",
        clean_up_tokenization_spaces=False  # Suppress the FutureWarning
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model
optimizer = Adam(learning_rate=2e-5)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs
)

# Step 12: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Step 2: Load dataset
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model
optimizer = Adam(learning_rate=2e-5)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs
)

# Step 12: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\ksvsu\AppData\Local\Temp\ipykernel_7956\1099600633.py:11: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# Step 2: Load dataset
df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model with learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=10000,  # You can adjust this based on your dataset size
    end_learning_rate=1e-6
)
optimizer = Adam(learning_rate=lr_schedule)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Add model checkpoint and TensorBoard for logging
checkpoint_callback = ModelCheckpoint(
    filepath='bert_model_best.h5',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

# Step 12: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[checkpoint_callback, tensorboard_callback]
)

# Step 13: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# C:\Users\ksvsu\AppData\Local\Temp\ipykernel_7956\3386992132.py:12: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', encoding='ISO-8859-1', header=None, on_bad_lines='skip')
# C:\Users\ksvsu\AppData\Roaming\Python\Python312\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# Step 2: Load dataset
df = pd.read_csv(
    r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', 
    encoding='ISO-8859-1', 
    header=None, 
    on_bad_lines='skip', 
    dtype={0: int, 1: int},  # Specify the correct dtypes for columns
    low_memory=False  # Avoid the mixed type warning
)
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Simplify target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf",
        clean_up_tokenization_spaces=False  # Suppress FutureWarning
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model with learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=10000,  # You can adjust this based on your dataset size
    end_learning_rate=1e-6
)
optimizer = Adam(learning_rate=lr_schedule)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Add model checkpoint and TensorBoard for logging
checkpoint_callback = ModelCheckpoint(
    filepath='bert_model_best.keras',  # Change to .keras format
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

# Step 12: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[checkpoint_callback, tensorboard_callback]
)

# Step 13: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File parsers.pyx:1161, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 12
#       9 from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
#      11 # Step 2: Load dataset
# ---> 12 df = pd.read_csv(
#      13     r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv',
#      14     encoding='ISO-8859-1',
#      15     header=None,
#      16     on_bad_lines='skip',
#      17     dtype={0: int, 1: int},  # Specify the correct dtypes for columns
#      18     low_memory=False  # Avoid the mixed type warning
#      19 )
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# Step 2: Load dataset without specifying dtypes (fixes mixed type issue)
df = pd.read_csv(
    r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', 
    encoding='ISO-8859-1', 
    header=None, 
    on_bad_lines='skip',  # Skip rows with bad data
    low_memory=False      # Avoid mixed type warning
)
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Clean and convert 'target' and 'id' columns to integers
# Use pd.to_numeric with errors='coerce' to convert non-integer values to NaN, then drop them
df['target'] = pd.to_numeric(df['target'], errors='coerce')
df['id'] = pd.to_numeric(df['id'], errors='coerce')

# Drop rows with NaN values in 'target' or 'id' (these rows had invalid data)
df.dropna(subset=['target', 'id'], inplace=True)

# Convert target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf",
        clean_up_tokenization_spaces=False  # Suppress FutureWarning
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model with learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=10000,  # Adjust based on dataset size
    end_learning_rate=1e-6
)
optimizer = Adam(learning_rate=lr_schedule)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Add model checkpoint and TensorBoard for logging
checkpoint_callback = ModelCheckpoint(
    filepath='bert_model_best.keras',  # Save in .keras format
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

# Step 12: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[checkpoint_callback, tensorboard_callback]
)

# Step 13: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# Step 2: Load dataset without specifying dtypes (fixes mixed type issue)
df = pd.read_csv(
    r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', 
    encoding='ISO-8859-1', 
    header=None, 
    on_bad_lines='skip',  # Skip rows with bad data
    low_memory=False      # Avoid mixed type warning
)
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Clean and convert 'target' and 'id' columns to integers
# Use pd.to_numeric with errors='coerce' to convert non-integer values to NaN, then drop them
df['target'] = pd.to_numeric(df['target'], errors='coerce')
df['id'] = pd.to_numeric(df['id'], errors='coerce')

# Drop rows with NaN values in 'target' or 'id' (these rows had invalid data)
df.dropna(subset=['target', 'id'], inplace=True)

# Convert target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf",
        clean_up_tokenization_spaces=False  # Suppress FutureWarning
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model with learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=10000,  # Adjust based on dataset size
    end_learning_rate=1e-6
)
optimizer = Adam(learning_rate=lr_schedule)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Add model checkpoint and TensorBoard for logging
checkpoint_callback = ModelCheckpoint(
    filepath='bert_model_best.keras',  # Save in .keras format
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

# Step 12: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[checkpoint_callback, tensorboard_callback]
)

# Step 13: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Step 1: Import necessary libraries
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# Step 2: Load dataset without specifying dtypes (fixes mixed type issue)
df = pd.read_csv(
    r'C:\Users\ksvsu\OneDrive\Desktop\Minor Project\sampled_data.csv', 
    encoding='ISO-8859-1', 
    header=None, 
    on_bad_lines='skip',  # Skip rows with bad data
    low_memory=False      # Avoid mixed type warning
)
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# Step 3: Clean and convert 'target' and 'id' columns to integers
# Use pd.to_numeric with errors='coerce' to convert non-integer values to NaN, then drop them
df['target'] = pd.to_numeric(df['target'], errors='coerce')
df['id'] = pd.to_numeric(df['id'], errors='coerce')

# Drop rows with NaN values in 'target' or 'id' (these rows had invalid data)
df.dropna(subset=['target', 'id'], inplace=True)

# Convert target labels (0 = negative, 4 = positive to binary 0 and 1)
df['target'] = df['target'].apply(lambda x: 1 if x == 4 else 0)

# Step 4: Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 5: Tokenize the text data
def tokenize_tweets(tweets, tokenizer, max_length=128):
    return tokenizer(
        tweets.tolist(),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="tf",
        clean_up_tokenization_spaces=True  # Explicitly set this to avoid the warning
    )

tokens = tokenize_tweets(df['text'], tokenizer)

# Step 6: Prepare inputs for TensorFlow
input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']

# Convert TensorFlow tensors to NumPy arrays
input_ids_np = input_ids.numpy()
attention_masks_np = attention_masks.numpy()
targets_np = df['target'].values

# Step 7: Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    input_ids_np, targets_np, test_size=0.2, random_state=42
)
train_masks, val_masks = train_test_split(attention_masks_np, test_size=0.2, random_state=42)

# Step 8: Convert data to TensorFlow Dataset format
def create_tf_dataset(inputs, masks, labels, batch_size=32):
    data = tf.data.Dataset.from_tensor_slices(({
        'input_ids': inputs,
        'attention_mask': masks
    }, labels))

    return data.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

batch_size = 32
train_dataset = create_tf_dataset(train_inputs, train_masks, train_labels, batch_size)
val_dataset = create_tf_dataset(val_inputs, val_masks, val_labels, batch_size)

# Step 9: Build the model
class BertForSentimentAnalysis(tf.keras.Model):
    def __init__(self, bert_model_name='bert-base-uncased', num_classes=2):
        super(BertForSentimentAnalysis, self).__init__()
        self.bert = TFBertModel.from_pretrained(bert_model_name)
        self.dropout = tf.keras.layers.Dropout(0.3)
        self.classifier = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token output
        x = self.dropout(cls_output)
        x = self.classifier(x)
        return x

model = BertForSentimentAnalysis()

# Step 10: Compile the model with learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=2e-5,
    decay_steps=10000,  # Adjust based on dataset size
    end_learning_rate=1e-6
)
optimizer = Adam(learning_rate=lr_schedule)
loss = SparseCategoricalCrossentropy()
metrics = [SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# Step 11: Add model checkpoint and TensorBoard for logging
checkpoint_callback = ModelCheckpoint(
    filepath='bert_model_best.keras',  # Save in .keras format
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

# Step 12: Train the model
epochs = 3  # You can adjust the number of epochs

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[checkpoint_callback, tensorboard_callback]
)

# Step 13: Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
